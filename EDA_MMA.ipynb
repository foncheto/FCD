# %% [markdown]
# #**REVISAREMOS EL DATASET DE LOS PELEADORES DE MMA QUE HAN PELEADO EN ALGUN EVENTO DE UFC, BELLATOR Y ONE.**
#
# #**WE WILL REVIEW THE DATASET OF MMA FIGHTERS WHO HAVE FIGHTED IN ANY UFC, BELLATOR AND ONE EVENT.**

# %% [markdown]
# #**Importamos las librerias que utilizaremos**
#
# **We import the libraries that we will use**

# %%
import pandas as pd
import numpy as np
from plotnine import *

# %% [markdown]
# #**Cargamos el archivo csv en un DataFrame**
#
# **We load the csv file in a DataFrame**

# %%
mma=pd.read_csv("/content/drive/MyDrive/FUNDAMENTOS DE CIENCIA DE DATOS/202202 SEMESTRE/pro_mma_fighters.csv")

# %%
mma.columns
# Out:
# Index(['url', 'fighter_name', 'nickname', 'birth_date', 'age', 'death_date',
#        'location', 'country', 'height', 'weight', 'association',
#        'weight_class', 'wins', 'wins_ko', 'wins_submission', 'wins_decision',
#        'wins_other', 'lossess', 'losses_ko', 'losses_submission',
#        'losses_decision', 'losses_other'],
#       dtype='object')

# %%
mma.head()
# Out:
#                                   url        fighter_name        nickname  \
# 0  /fighter/Kharun-Atlangeriev-167431  Kharun Atlangeriev        Predator
# 1         /fighter/Shojin-Miki-157565         Shojin Miki  Mini Margarito
# 2          /fighter/Ryan-Keenan-33827         Ryan Keenan        Who Dat?
# 3        /fighter/Dustin-Jacoby-73825       Dustin Jacoby      The Hanyak
# 4   /fighter/Richardson-Moreira-72825  Richardson Moreira    Rick Monstro
#
#    birth_date   age death_date              location        country height  \
# 0  05/10/1992  28.0        NaN                   NaN         Russia  5'10"
# 1         NaN   NaN        NaN      Honolulu, Hawaii  United States   5'9"
# 2  15/06/1985  36.0        NaN   Windermere, Florida  United States   6'0"
# 3  04/04/1988  33.0        NaN  Arenzville, Illinois  United States   6'4"
# 4  31/03/1984  37.0        NaN   Campinas, Sao Paulo         Brazil   6'2"
#
# ...

# %% [markdown]
# No podemos ver todas las columnas de nuestro DataFrame. Para solucionar eso, utilizamos pd.set_option(('display.max_columns', n°_columnas)
#
# We can't see all the columns of our DataFrame. To fix that, we use pd.set_option(('display.max_columns', n°_columns)

# %%
pd.set_option('display.max_columns', 24)
mma.head(3)
# Out:
#                                   url        fighter_name        nickname  \
# 0  /fighter/Kharun-Atlangeriev-167431  Kharun Atlangeriev        Predator
# 1         /fighter/Shojin-Miki-157565         Shojin Miki  Mini Margarito
# 2          /fighter/Ryan-Keenan-33827         Ryan Keenan        Who Dat?
#
#    birth_date   age death_date             location        country height  \
# 0  05/10/1992  28.0        NaN                  NaN         Russia  5'10"
# 1         NaN   NaN        NaN     Honolulu, Hawaii  United States   5'9"
# 2  15/06/1985  36.0        NaN  Windermere, Florida  United States   6'0"
#
#     weight     association weight_class  wins  wins_ko  wins_submission  \
# 0  155 lbs        OFS Team  Lightweight    11        5                5
# 1  125 lbs     HMC Academy    Flyweight     6        2                4
# 2  155 lbs  Gracie Orlando  Lightweight     6        3                3
#
#    wins_decision  wins_other  lossess  losses_ko  losses_submission  \
# ...

# %% [markdown]
# ##**Revisamos el Dataframe**
#
# **We review the Dataframe**

# %%
mma.shape
# Out:
# (5151, 22)

# %% [markdown]
# Tenemos en nuestro Dataframe 5.151 filas y 22 columnas
#
# We have in our Dataframe 5,151 rows and 22 columns

# %%
mma.describe()
# Out:
#                age         wins      wins_ko  wins_submission  wins_decision  \
# count  4002.000000  5151.000000  5151.000000      5151.000000    5151.000000
# mean     35.320840    10.844302     4.050087         3.821394       2.909532
# std       6.639803     9.287356     4.625994         4.533450       3.280180
# min      20.000000     0.000000     0.000000         0.000000       0.000000
# 25%      31.000000     4.000000     1.000000         1.000000       0.000000
# 50%      35.000000     9.000000     3.000000         3.000000       2.000000
# 75%      39.000000    15.000000     6.000000         6.000000       4.000000
# max      66.000000   255.000000   143.000000       104.000000      31.000000
#
#        wins_other      lossess    losses_ko  losses_submission  \
# count  429.000000  5151.000000  5151.000000        5151.000000
# mean     0.759907    10.844302     1.778101           1.564939
# std      0.746128     9.287356     2.025247           2.127765
# ...

# %%
mma.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5151 entries, 0 to 5150
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   url                5151 non-null   object
#  1   fighter_name       5148 non-null   object
#  2   nickname           3205 non-null   object
#  3   birth_date         4036 non-null   object
#  4   age                4002 non-null   float64
#  5   death_date         37 non-null     object
#  6   location           4639 non-null   object
#  7   country            5129 non-null   object
#  8   height             5151 non-null   object
#  9   weight             5151 non-null   object
#  10  association        4424 non-null   object
#  11  weight_class       5121 non-null   object
#  12  wins               5151 non-null   int64
#  13  wins_ko            5151 non-null   int64
#  14  wins_submission    5151 non-null   int64
#  15  wins_decision      5151 non-null   int64
# ...

# %% [markdown]
# #**Revisamos filas duplicadas**
#
# #**We check for duplicate rows**

# %%
mma[mma.duplicated()]
# Out:
# Empty DataFrame
# Columns: [url, fighter_name, nickname, birth_date, age, death_date, location, country, height, weight, association, weight_class, wins, wins_ko, wins_submission, wins_decision, wins_other, lossess, losses_ko, losses_submission, losses_decision, losses_other]
# Index: []

# %% [markdown]
# No tenemos filas duplicadas que tengamos que eliminar o revisar su razonabilidad
#
# We have no duplicate rows that we need to remove or review for reasonableness

# %% [markdown]
# #**Revisamos NA´s**
#
# #**Review NA's**

# %%
mma.isna().sum()
# Out:
# url                     0
# fighter_name            3
# nickname             1946
# birth_date           1115
# age                  1149
# death_date           5114
# location              512
# country                22
# height                  0
# weight                  0
# association           727
# weight_class           30
# wins                    0
# wins_ko                 0
# wins_submission         0
# wins_decision           0
# wins_other           4722
# lossess                 0
# losses_ko               0
# losses_submission       0
# losses_decision         0
# losses_other         4722
# dtype: int64

# %% [markdown]
# ###**Las columnas url, nickname, las eliminamos. No aportan a nuestro análisis**.
#
# ###**The url, nickname columns, we remove them. They do not contribute to our analysis**.

# %%
mma=mma.drop(columns=(['url','nickname']))

# %%
mma.head(3)
# Out:
#          fighter_name  birth_date   age death_date             location  \
# 0  Kharun Atlangeriev  05/10/1992  28.0        NaN                  NaN
# 1         Shojin Miki         NaN   NaN        NaN     Honolulu, Hawaii
# 2         Ryan Keenan  15/06/1985  36.0        NaN  Windermere, Florida
#
#          country height   weight     association weight_class  wins  wins_ko  \
# 0         Russia  5'10"  155 lbs        OFS Team  Lightweight    11        5
# 1  United States   5'9"  125 lbs     HMC Academy    Flyweight     6        2
# 2  United States   6'0"  155 lbs  Gracie Orlando  Lightweight     6        3
#
#    wins_submission  wins_decision  wins_other  lossess  losses_ko  \
# 0                5              1         NaN       11          0
# 1                4              0         NaN        6          2
# 2                3              0         NaN        6          1
#
#    losses_submission  losses_decision  losses_other
# ...

# %% [markdown]
# **¿Como vamos con los na´s?**
#
# **How are we doing with the na's?**

# %%
mma.isna().sum()
# Out:
# fighter_name            3
# birth_date           1115
# age                  1149
# death_date           5114
# location              512
# country                22
# height                  0
# weight                  0
# association           727
# weight_class           30
# wins                    0
# wins_ko                 0
# wins_submission         0
# wins_decision           0
# wins_other           4722
# lossess                 0
# losses_ko               0
# losses_submission       0
# losses_decision         0
# losses_other         4722
# dtype: int64

# %% [markdown]
# **Revisamos las filas donde no conocemos el nombre de los peleadores**
#
# **We check the rows where we do not know the name of the fighters**

# %%
mma['fighter_name'].isna()
mma[mma['fighter_name'].isna()]
# Out:
#      fighter_name  birth_date   age death_date                 location  \
# 3715          NaN  12/02/1986  35.0        NaN  Albuquerque, New Mexico
# 3978          NaN  08/06/1984  37.0        NaN        Las Vegas, Nevada
# 4740          NaN  23/01/1988  33.0        NaN     Carlsbad, California
#
#             country height   weight       association   weight_class  wins  \
# 3715  United States   5'8"  145 lbs  Jackson-Wink MMA  Featherweight     6
# 3978  United States   5'9"  145 lbs    Xtreme Couture  Featherweight    13
# 4740  United States  5'11"  185 lbs     Blackline MMA   Middleweight     9
#
#       wins_ko  wins_submission  wins_decision  wins_other  lossess  losses_ko  \
# 3715        2                4              0         NaN        6          0
# 3978        2                6              5         NaN       13          4
# 4740        6                0              3         NaN        9          5
#
#       losses_submission  losses_decision  losses_other
# ...

# %% [markdown]
# Los nombres de peleadores con NA´s de los dejaremos como Peleador NN
#
# We will leave the names of fighters with NA's as Peleador NN

# %%
mma['fighter_name'][mma['fighter_name'].isna()]='Peleador NN'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Chequeamos que ya no tenemos nombres de peladores con NA´s
mma[mma['fighter_name'].isna()]
# Out:
# Empty DataFrame
# Columns: [fighter_name, birth_date, age, death_date, location, country, height, weight, association, weight_class, wins, wins_ko, wins_submission, wins_decision, wins_other, lossess, losses_ko, losses_submission, losses_decision, losses_other]
# Index: []

# %%
mma[mma['fighter_name']=='Peleador NN']
# Out:
#      fighter_name  birth_date   age death_date                 location  \
# 3715  Peleador NN  12/02/1986  35.0        NaN  Albuquerque, New Mexico
# 3978  Peleador NN  08/06/1984  37.0        NaN        Las Vegas, Nevada
# 4740  Peleador NN  23/01/1988  33.0        NaN     Carlsbad, California
#
#             country height   weight       association   weight_class  wins  \
# 3715  United States   5'8"  145 lbs  Jackson-Wink MMA  Featherweight     6
# 3978  United States   5'9"  145 lbs    Xtreme Couture  Featherweight    13
# 4740  United States  5'11"  185 lbs     Blackline MMA   Middleweight     9
#
#       wins_ko  wins_submission  wins_decision  wins_other  lossess  losses_ko  \
# 3715        2                4              0         NaN        6          0
# 3978        2                6              5         NaN       13          4
# 4740        6                0              3         NaN        9          5
#
#       losses_submission  losses_decision  losses_other
# ...

# %% [markdown]
# Como tenemos muchos na´s con las variables birth_date, death_date y age. Generaremos una nueva columna que indique si el peleador esta vivo o fallecio y eliminaremos estas columnas.
#
# Since we have many na's with the variables birth_date, death_date and age. We will generate a new column that indicates if the fighter is alive or deceased and we will eliminate these columns.

# %%
mma['Estado'] = np.where(mma['death_date'].isna(), 'Vivo', 'Fallecido')
mma.head(2)
# Out:
#          fighter_name  birth_date   age death_date          location  \
# 0  Kharun Atlangeriev  05/10/1992  28.0        NaN               NaN
# 1         Shojin Miki         NaN   NaN        NaN  Honolulu, Hawaii
#
#          country height   weight  association weight_class  wins  wins_ko  \
# 0         Russia  5'10"  155 lbs     OFS Team  Lightweight    11        5
# 1  United States   5'9"  125 lbs  HMC Academy    Flyweight     6        2
#
#    wins_submission  wins_decision  wins_other  lossess  losses_ko  \
# 0                5              1         NaN       11          0
# 1                4              0         NaN        6          2
#
#    losses_submission  losses_decision  losses_other Estado
# 0                  1                1           NaN   Vivo
# 1                  0                5           NaN   Vivo

# %% [markdown]
# Ahora eliminamos las columnas birth_date, death_date y age.
#
# Now we remove the birth_date, death_date and age columns.

# %%
mma=mma.drop(columns=(['birth_date','age','death_date']))

# %%
# mma.columns
mma.head()
# Out:
#          fighter_name              location        country height   weight  \
# 0  Kharun Atlangeriev                   NaN         Russia  5'10"  155 lbs
# 1         Shojin Miki      Honolulu, Hawaii  United States   5'9"  125 lbs
# 2         Ryan Keenan   Windermere, Florida  United States   6'0"  155 lbs
# 3       Dustin Jacoby  Arenzville, Illinois  United States   6'4"  205 lbs
# 4  Richardson Moreira   Campinas, Sao Paulo         Brazil   6'2"  205 lbs
#
#       association       weight_class  wins  wins_ko  wins_submission  \
# 0        OFS Team        Lightweight    11        5                5
# 1     HMC Academy          Flyweight     6        2                4
# 2  Gracie Orlando        Lightweight     6        3                3
# 3       Factory X  Light Heavyweight    14        9                1
# 4   Team Nogueira  Light Heavyweight     8        2                5
#
#    wins_decision  wins_other  lossess  losses_ko  losses_submission  \
# ...

# %% [markdown]
# ¿Como vamos con los na´s?
#
# How are we doing with the na's?

# %%
mma.isna().sum()
# Out:
# fighter_name            0
# location              512
# country                22
# height                  0
# weight                  0
# association           727
# weight_class           30
# wins                    0
# wins_ko                 0
# wins_submission         0
# wins_decision           0
# wins_other           4722
# lossess                 0
# losses_ko               0
# losses_submission       0
# losses_decision         0
# losses_other         4722
# Estado                  0
# dtype: int64

# %% [markdown]
# Para las variables location, country, association y weight_class, rellenaremos los na´s con "sin_location", "sin_country","sin_Association" y "sin_weight_class"
#
# For the variables location, country, association and weight_class, we will fill the na's with "sin_location", "sin_country","sin_Association" and "sin_weight_class"

# %%
mma['location'][mma['location'].isna()]='Sin location'
mma['country'][mma['country'].isna()]='Sin country'
mma['association'][mma['association'].isna()]='Sin association'
mma['weight_class'][mma['weight_class'].isna()]='Sin weight_class'

# %% [markdown]
# ¿Como seguimos con los na´s?
#
# How do we continue with the na's?

# %%
mma.isna().sum()
# Out:
# fighter_name            0
# location                0
# country                 0
# height                  0
# weight                  0
# association             0
# weight_class            0
# wins                    0
# wins_ko                 0
# wins_submission         0
# wins_decision           0
# wins_other           4722
# lossess                 0
# losses_ko               0
# losses_submission       0
# losses_decision         0
# losses_other         4722
# Estado                  0
# dtype: int64

# %% [markdown]
# Revisamos los na´s de wins_other y losses_other
#
# We check the na's of wins_other and losses_other

# %%
print(mma['losses_other'].unique())
print(mma['wins_other'].unique())
# mma.info()
# Out:
# [nan  0.  1.  2.  3.]
# [nan  1.  0.  2.  4.  5.  3.]

# %% [markdown]
# Cambiaremos los na´s por 0´s considerando que la suma de wins_ko + wins_submission + wins_decision es igual a wins.
#
# Cambiaremos los na´s por 0´s considerando que la suma de wins_ko + wins_submission + wins_decision es igual a wins.

# %%
mma['wins_other'][mma['wins_other'].isna()]=0
mma['losses_other'][mma['losses_other'].isna()]=0

# %%
# Ya no tenemos na´s
mma.isna().sum()
# Out:
# fighter_name         0
# location             0
# country              0
# height               0
# weight               0
# association          0
# weight_class         0
# wins                 0
# wins_ko              0
# wins_submission      0
# wins_decision        0
# wins_other           0
# lossess              0
# losses_ko            0
# losses_submission    0
# losses_decision      0
# losses_other         0
# Estado               0
# dtype: int64

# %% [markdown]
# ###**Revisamos la consistencia de las variables**
#
# ###**We check the consistency of the variables**

# %%
mma.head(1)
# Out:
#          fighter_name      location country height   weight association  \
# 0  Kharun Atlangeriev  Sin location  Russia  5'10"  155 lbs    OFS Team
#
#   weight_class  wins  wins_ko  wins_submission  wins_decision  wins_other  \
# 0  Lightweight    11        5                5              1         0.0
#
#    lossess  losses_ko  losses_submission  losses_decision  losses_other Estado
# 0       11          0                  1                1           0.0   Vivo

# %% [markdown]
# Nos parece que la columna de wins es igual a la de lossess. Esto lo revisaremos con la función equals.
#
# It seems to us that the wins column is the same as the lossess column. We will check this with the equals function.
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.equals.html
#
# Revisemos.
#
# Let's review.

# %%
mma['wins'].equals(mma['lossess'])
# Out:
# True

# %% [markdown]
# Tal como creiamos, ambas columnas son iguales. ¿Que hacemos?
#
# Crearemos una columna "perdidas" que sea la suma de losses_ko	+ losses_submission	+ losses_decision	+ losses_other y luego eliminaremos estas columnas
#
# As we thought, both columns are equal. What do we do?
#
# We will create a "losses" column that is the sum of losses_ko + losses_submission + losses_decision + losses_other and then delete these columns

# %%
mma['perdidas']=mma['losses_ko']+mma['losses_submission']+mma['losses_decision']+mma['losses_other']

# %%
# Validamos que este creada
mma.head(2)
# Out:
#          fighter_name          location        country height   weight  \
# 0  Kharun Atlangeriev      Sin location         Russia  5'10"  155 lbs
# 1         Shojin Miki  Honolulu, Hawaii  United States   5'9"  125 lbs
#
#    association weight_class  wins  wins_ko  wins_submission  wins_decision  \
# 0     OFS Team  Lightweight    11        5                5              1
# 1  HMC Academy    Flyweight     6        2                4              0
#
#    wins_other  lossess  losses_ko  losses_submission  losses_decision  \
# 0         0.0       11          0                  1                1
# 1         0.0        6          2                  0                5
#
#    losses_other Estado  perdidas
# 0           0.0   Vivo       2.0
# 1           0.0   Vivo       7.0

# %% [markdown]
# Luego, eliminamos la columna lossess
#
# Then, you remove the lossess column

# %%
mma.drop(columns=(['lossess']), inplace=True)
# mma=mma.drop(columns=(['lossess']))

# %%
mma.head(2)
# Out:
#          fighter_name          location        country height   weight  \
# 0  Kharun Atlangeriev      Sin location         Russia  5'10"  155 lbs
# 1         Shojin Miki  Honolulu, Hawaii  United States   5'9"  125 lbs
#
#    association weight_class  wins  wins_ko  wins_submission  wins_decision  \
# 0     OFS Team  Lightweight    11        5                5              1
# 1  HMC Academy    Flyweight     6        2                4              0
#
#    wins_other  losses_ko  losses_submission  losses_decision  losses_other  \
# 0         0.0          0                  1                1           0.0
# 1         0.0          2                  0                5           0.0
#
#   Estado  perdidas
# 0   Vivo       2.0
# 1   Vivo       7.0

# %% [markdown]
# Ahora, eliminaremos las columnas win_ko, wins_submission	wins_decision	wins_other, losses_ko, losses_submission,	losses_decision, losses_other
#
# Now, we will remove the columns win_ko, wins_submission wins_decision wins_other, losses_ko, losses_submission, losses_decision, losses_other

# %%
mma=mma.drop(columns=(['wins_ko', 'wins_submission','wins_decision','wins_other','losses_ko','losses_submission','losses_decision','losses_other']))

# %%
mma.head()
# Out:
#          fighter_name              location        country height   weight  \
# 0  Kharun Atlangeriev          Sin location         Russia  5'10"  155 lbs
# 1         Shojin Miki      Honolulu, Hawaii  United States   5'9"  125 lbs
# 2         Ryan Keenan   Windermere, Florida  United States   6'0"  155 lbs
# 3       Dustin Jacoby  Arenzville, Illinois  United States   6'4"  205 lbs
# 4  Richardson Moreira   Campinas, Sao Paulo         Brazil   6'2"  205 lbs
#
#       association       weight_class  wins Estado  perdidas
# 0        OFS Team        Lightweight    11   Vivo       2.0
# 1     HMC Academy          Flyweight     6   Vivo       7.0
# 2  Gracie Orlando        Lightweight     6   Vivo       2.0
# 3       Factory X  Light Heavyweight    14   Vivo       5.0
# 4   Team Nogueira  Light Heavyweight     8   Vivo       5.0

# %% [markdown]
# Ahora que tenemos nuestro Dataframe "limpio", revisamos las dimensiones
#
# Now that we have our "clean" Dataframe, we check the dimensions

# %%
mma.shape
# Out:
# (5151, 10)

# %% [markdown]
# Mantenemos la misma cantidad de filas, pero ahora con 10 columnas
#
# We keep the same number of rows, but now with 10 columns

# %% [markdown]
# ###**Ahora comenzaremos a revisar cada una de las variables que tenemos en nuestro DataFrame final**
#
# ###**Now we'll start going through each of the variables we have in our final DataFrame**

# %% [markdown]
# * fighter_name

# %%
#Cuantos nombres hay?
mma['fighter_name'].nunique()
# Out:
# 5141

# %% [markdown]
# Revisamos si algún nombre de peleador se encuentra repetido
#
# We check if any fighter name is repeated

# %%
nombres=mma["fighter_name"].groupby(mma["fighter_name"]).count()
nombres=pd.DataFrame({"fighter_name":nombres.index,"cantidad":np.array(nombres)})
nombres.sort_values(by='cantidad', ascending=False).head(10)
# Out:
#          fighter_name  cantidad
# 3807      Peleador NN         3
# 3897     Rafael Silva         2
# 4762     Tony Johnson         2
# 4414   Shane Campbell         2
# 3177   Marcus Aurelio         2
# 4551    Steven Graham         2
# 674       Bruno Silva         2
# 3320  Maurice Jackson         2
# 750     Casey Johnson         2
# 3443     Mike Nickels         1

# %% [markdown]
# Revisamos si los nombres repetidos corresponden al mismo peleador o no.
#
# We check if the repeated names correspond to the same fighter or not.

# %%
# mma[mma['fighter_name']=='Rafael Silva']
# mma[mma['fighter_name']=='Tony Johnson']
# mma[mma['fighter_name']=='Shane Campbell']
# mma[mma['fighter_name']=='Marcus Aurelio']
# mma[mma['fighter_name']=='Steven Graham']
# mma[mma['fighter_name']=='Bruno Silva']
# mma[mma['fighter_name']=='Maurice Jackson']
mma[mma['fighter_name']=='Casey Johnson']
# Out:
#        fighter_name                 location        country height   weight  \
# 2195  Casey Johnson         Middleton, Idaho  United States   5'7"  135 lbs
# 4419  Casey Johnson  Raleigh, North Carolina  United States   5'8"  145 lbs
#
#           association   weight_class  wins Estado  perdidas
# 2195      Freak-Jitsu   Bantamweight     7   Vivo       5.0
# 4419  Sin association  Featherweight     4   Vivo       5.0

# %% [markdown]
# Los peleadores son todos diferentes, a pesar de tener el mismo nombre.
#
# The fighters are all different, despite having the same name.

# %% [markdown]
# * Location

# %%
# Tenemos 2.144 ubicaciones unicas
# We have 2,144 unique locations
mma['location'].nunique()
# Out:
# 2144

# %%
mma.head()
# Out:
#          fighter_name              location        country height   weight  \
# 0  Kharun Atlangeriev          Sin location         Russia  5'10"  155 lbs
# 1         Shojin Miki      Honolulu, Hawaii  United States   5'9"  125 lbs
# 2         Ryan Keenan   Windermere, Florida  United States   6'0"  155 lbs
# 3       Dustin Jacoby  Arenzville, Illinois  United States   6'4"  205 lbs
# 4  Richardson Moreira   Campinas, Sao Paulo         Brazil   6'2"  205 lbs
#
#       association       weight_class  wins Estado  perdidas
# 0        OFS Team        Lightweight    11   Vivo       2.0
# 1     HMC Academy          Flyweight     6   Vivo       7.0
# 2  Gracie Orlando        Lightweight     6   Vivo       2.0
# 3       Factory X  Light Heavyweight    14   Vivo       5.0
# 4   Team Nogueira  Light Heavyweight     8   Vivo       5.0

# %% [markdown]
# Eliminaremos el primer lugar indicado en location
#
# We will remove the first place indicated in location

# %%
# mma['location'][3][index::]
for i in range(0,mma.shape[0]):
  index = mma['location'][i].find(',')
  mma['location'][i]=mma['location'][i][index+2::].strip()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
mma.head()
# Out:
#          fighter_name     location        country height   weight  \
# 0  Kharun Atlangeriev  in location         Russia  5'10"  155 lbs
# 1         Shojin Miki       Hawaii  United States   5'9"  125 lbs
# 2         Ryan Keenan      Florida  United States   6'0"  155 lbs
# 3       Dustin Jacoby     Illinois  United States   6'4"  205 lbs
# 4  Richardson Moreira    Sao Paulo         Brazil   6'2"  205 lbs
#
#       association       weight_class  wins Estado  perdidas
# 0        OFS Team        Lightweight    11   Vivo       2.0
# 1     HMC Academy          Flyweight     6   Vivo       7.0
# 2  Gracie Orlando        Lightweight     6   Vivo       2.0
# 3       Factory X  Light Heavyweight    14   Vivo       5.0
# 4   Team Nogueira  Light Heavyweight     8   Vivo       5.0

# %%
mma['location'][2002]
mma['location'].nunique()
# Out:
# 773

# %% [markdown]
# **Country**

# %%
# N° de paises
mma['country'].nunique()
# Out:
# 127

# %% [markdown]
# ¿Hay peleadores Chilenos?
#
# Are there Chilean fighters?

# %%
# mma['country'].unique()
mma_chile=mma[mma['country']=='Chile']
mma_chile
# Out:
#             fighter_name     location country height   weight  \
# 180          Diego Rivas        emuco   Chile   5'9"  145 lbs
# 689      Pablo Villaseca      antiago   Chile   5'7"  145 lbs
# 2826  Ignacio Bahamondes  in location   Chile   6'1"  155 lbs
#
#               association   weight_class  wins Estado  perdidas
# 180        Elemental Dojo  Featherweight     7   Vivo       2.0
# 689         Team Weichafe  Featherweight    14   Vivo       6.0
# 2826  Valle Flow Striking    Lightweight    11   Vivo       4.0

# %% [markdown]
# ¿Como están los Chilenos respecto de los otros peleadores?

# %%
mma['wins'].mean()
# Out:
# 10.84430207726655

# %%
(ggplot(mma_chile)+
 aes(x="fighter_name",y="wins",fill="association")+
 geom_bar(stat="identity")+
 theme_minimal()+
 ylab("Cantidad Peleas Ganadas")+
 xlab("Peleador")+
 ggtitle("Peleas ganadas peleadores Chilenos")
)
# Out:
# <ggplot: (8773118887837)>

# %% [markdown]
# Buscamos los 10 paises con más peleadores
#
# We look for the 10 countries with the most fighters

# %%
paises=mma["country"].groupby(mma["country"]).count()
paises=pd.DataFrame({"country":paises.index,"cantidad":np.array(paises)})
diez=paises.sort_values(by='cantidad', ascending=False).head(10)
diez
# Out:
#            country  cantidad
# 119  United States      2821
# 14          Brazil       403
# 38         England       181
# 23           China       175
# 60           Japan       145
# 20          Canada       128
# 94          Russia       120
# 6        Australia        64
# 89     Philippines        60
# 57          Israel        55

# %%
(ggplot(diez)+
 aes(x="country", y="cantidad", color="country", fill="country")+
 geom_bar(stat="identity",alpha=0.5)+
 theme_xkcd()+
 ggtitle("10 paises con más peleadores")+
 xlab("Paises")+
 ylab("Cantidad")+
 theme(legend_position="bottom",legend_box_spacing=1,legend_box="horizontal",axis_text_x=element_text(angle=50))

)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 225 missing from current font.
# <ggplot: (8773116181145)>

# %% [markdown]
# * Height

# %%
mma.head()
# Out:
#          fighter_name     location        country height   weight  \
# 0  Kharun Atlangeriev  in location         Russia  5'10"  155 lbs
# 1         Shojin Miki       Hawaii  United States   5'9"  125 lbs
# 2         Ryan Keenan      Florida  United States   6'0"  155 lbs
# 3       Dustin Jacoby     Illinois  United States   6'4"  205 lbs
# 4  Richardson Moreira    Sao Paulo         Brazil   6'2"  205 lbs
#
#       association       weight_class  wins Estado  perdidas
# 0        OFS Team        Lightweight    11   Vivo       2.0
# 1     HMC Academy          Flyweight     6   Vivo       7.0
# 2  Gracie Orlando        Lightweight     6   Vivo       2.0
# 3       Factory X  Light Heavyweight    14   Vivo       5.0
# 4   Team Nogueira  Light Heavyweight     8   Vivo       5.0

# %% [markdown]
# ¿Cuantos valores unicos tenemos?
#
# How many unique values do we have?

# %%
mma['height'].nunique()
# Out:
# 28

# %% [markdown]
# ¿Que tipo de datos es height?
#
# What data type is height?

# %%
type(mma['height'][0])
# Out:
# str

# %%
(
ggplot(mma)+
aes(x="height",color="height",fill="height")+
geom_histogram()+
theme(legend_position="right",legend_box_spacing=1,legend_box="horizontal",axis_text_x=element_text(angle=50))
)
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/stats/stat_bin.py:95: PlotnineWarning: 'stat_bin()' using 'bins = 26'. Pick better value with 'binwidth'.
# <ggplot: (8773113834605)>

# %% [markdown]
# **Weight**

# %% [markdown]
# ¿Cuantos tenemos en esta variable? ¿De que tipo es?
#
# How many values do we have in this variable? What type is it?

# %%
print(mma['weight'].nunique())
print(type(mma['weight'][0]))
# Out:
# 176
# <class 'str'>

# %%
mma.head()
# Out:
#          fighter_name     location        country height   weight  \
# 0  Kharun Atlangeriev  in location         Russia  5'10"  155 lbs
# 1         Shojin Miki       Hawaii  United States   5'9"  125 lbs
# 2         Ryan Keenan      Florida  United States   6'0"  155 lbs
# 3       Dustin Jacoby     Illinois  United States   6'4"  205 lbs
# 4  Richardson Moreira    Sao Paulo         Brazil   6'2"  205 lbs
#
#       association       weight_class  wins Estado  perdidas
# 0        OFS Team        Lightweight    11   Vivo       2.0
# 1     HMC Academy          Flyweight     6   Vivo       7.0
# 2  Gracie Orlando        Lightweight     6   Vivo       2.0
# 3       Factory X  Light Heavyweight    14   Vivo       5.0
# 4   Team Nogueira  Light Heavyweight     8   Vivo       5.0

# %% [markdown]
# Tenemos 176 valores diferentes y el tipo de dato es un string
#
# We have 176 different values and the data type is a string

# %% [markdown]
# Vamos a transformar esta variable en float
# Primero tenemos que eliminar " lbs"
#
# We are going to transform this variable into float
# First we have to remove "lbs"

# %%
for i in range(0,mma.shape[0]):
  mma['weight'][i]=mma['weight'][i].replace(' lbs','')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
mma.head(2)
# Out:
#          fighter_name     location        country height weight  association  \
# 0  Kharun Atlangeriev  in location         Russia  5'10"    155     OFS Team
# 1         Shojin Miki       Hawaii  United States   5'9"    125  HMC Academy
#
#   weight_class  wins Estado  perdidas
# 0  Lightweight    11   Vivo       2.0
# 1    Flyweight     6   Vivo       7.0

# %%
mma['weight_class'].nunique()
# Out:
# 13

# %% [markdown]
# Pasamos la variable weight de string a float
#
# We pass the weight variable from string to float

# %%
mma['weight']=mma['weight'].astype('float')
type(mma['weight'][0])
# Out:
# numpy.float64

# %% [markdown]
# Ahora nuestra variable tiene un valor numerico
#
# Now our variable has a numeric value

# %%
(ggplot(mma)+
 aes(y="weight",x=0)+
 geom_boxplot()+
 scale_x_continuous(breaks=None)+ #Este comando sirve para setear la cuadrícula del eje x. Cuando breaks=None se elimina la cuadrícula.
                                  # This command is used to set the x-axis grid. When breaks=None the grid is removed.
 xlab("X")+
 theme_xkcd()+
 ylab("Weight")
+ggtitle("Distribucion de peso")
)
# Out:
# <ggplot: (8773113655457)>

# %%
mma['weight'].median()
# Out:
# 155.0

# %%
(ggplot(mma)+
 aes(x=0,y="weight",colour="Estado")+
 geom_boxplot()+
 scale_x_continuous(breaks=None)+ #Este comando sirve para setear la cuadrícula del eje x. Cuando breaks=None se elimina la cuadrícula.
                                  # This command is used to set the x-axis grid. When breaks=None the grid is removed.
 theme_minimal()+
 ylab("Weight")
 +ggtitle("Distribucion de peso")+
 facet_wrap('Estado')
)
# Out:
# <ggplot: (8773113630717)>

# %% [markdown]
# ¿Que peleador pesa 600 lbs?
#
# Which fighter weighs 600 lbs?

# %%
mma[mma['weight']==mma['weight'].max()]
# Out:
#             fighter_name    location        country height  weight  \
# 790  Emmanuel Yarborough  New Jersey  United States   6'8"   600.0
#
#     association       weight_class  wins     Estado  perdidas
# 790   Freelance  Super Heavyweight     1  Fallecido       2.0

# %% [markdown]
# **Association**

# %% [markdown]
# **weight_class**

# %%
mma['weight_class'].nunique()
# Out:
# 13

# %% [markdown]
# * Cantidad de peleadores por weight_class / country
#
# * Number of fighters by weight_class / country

# %%
# wc=mma.groupby(["weight_class","country"]).count()
# wc=pd.DataFrame(wc.sort_values(by='weight_class', ascending=False).agg('fighter_name'))
# wc

# %%
wc=mma.groupby(["weight_class"]).count()
wc=pd.DataFrame(wc.agg('fighter_name')).sort_values(by='fighter_name', ascending=False)
wc
# Out:
#                    fighter_name
# weight_class
# Welterweight                825
# Lightweight                 818
# Featherweight               771
# Bantamweight                607
# Middleweight                588
# Heavyweight                 459
# Flyweight                   410
# Light Heavyweight           396
# Strawweight                 190
# Atomweight                   31
# Sin weight_class             30
# Super Heavyweight            24
# Minimumweight                 2

# %%
(
ggplot(mma)+
aes(x="weight_class")+
geom_histogram()+
theme_minimal()+
theme(legend_position="right",legend_box_spacing=1,legend_box="horizontal",axis_text_x=element_text(angle=90))
)
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/stats/stat_bin.py:95: PlotnineWarning: 'stat_bin()' using 'bins = 21'. Pick better value with 'binwidth'.
# <ggplot: (8773113628801)>

# %% [markdown]
# **wins & lossess**

# %%
(ggplot(mma)+
aes(x="wins",y="perdidas",fill="country")+
geom_point()+
theme_xkcd()+
ggtitle("Grafico Wins vs Perdidas")+
guides(fill=False) #Este comando elimina la leyenda asociada a fill
)
# Out:
# <ggplot: (8773113514585)>

# %% [markdown]
# Como tenemos muchos paises, vamos a dejar los peleadores de los 9 paises con más peleadores
#
# As we have many countries, we are going to leave the fighters of the 9 countries with the most fighters

# %%
mma2=mma[(mma['country'] == 'United States') | (mma['country'] == 'Brazil') | (mma['country'] == 'England') | (mma['country'] == 'China') | (mma['country'] == 'Japan') 
| (mma['country'] == 'Canada') | (mma['country'] == 'Russia') | (mma['country'] == 'Australia') | (mma['country'] == 'Philippines') ]

mma2.shape
# Out:
# (4097, 10)

# %%
(ggplot(mma2)+
 aes(x=0,y="wins",colour="country")+
 geom_boxplot()+
 scale_x_continuous(breaks=None)+ #Este comando sirve para setear la cuadrícula del eje x. Cuando breaks=None se elimina la cuadrícula.
                                  # This command is used to set the x-axis grid. When breaks=None the grid is removed.
 theme_minimal()+
 ylab("Wins")
+ggtitle("Distribucion de wins")+
 facet_wrap('country')
)
# Out:
# <ggplot: (8773113542469)>

# %%
mma[mma['wins']==mma['wins'].max()]
# Out:
#        fighter_name location        country height  weight  \
# 2908  Travis Fulton     Iowa  United States   6'0"   205.0
#
#                 association       weight_class  wins     Estado  perdidas
# 2908  Team Peak Performance  Light Heavyweight   255  Fallecido      54.0

# %% [markdown]
# Eliminaremos el outlier de United States

# %%
mma2['wins'].max()
mma2[mma2['wins']==mma2['wins'].max()]
mma2.drop([2908], axis=0, inplace=True)
# mma2=mma2.drop([2908], axis=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
(ggplot(mma2)+
 aes(x=0,y="wins",colour="country")+
 geom_boxplot()+
 scale_x_continuous(breaks=None)+ #Este comando sirve para setear la cuadrícula del eje x. Cuando breaks=None se elimina la cuadrícula.
                                  # This command is used to set the x-axis grid. When breaks=None the grid is removed.
 theme_minimal()+
 ylab("Wins")
+ggtitle("Distribucion de wins")+
 facet_wrap('country')
)
# Out:
# <ggplot: (8773113652461)>

# %%
mma3=mma[(mma['country'] == 'United States') | (mma['country'] == 'Brazil') | (mma['country'] == 'England') ] 

mma3.shape
# Out:
# (3405, 10)

# %%
(ggplot(mma3)+
 aes(x=0,y="wins",colour="country")+
 geom_boxplot()+
 scale_x_continuous(breaks=None)+ #Este comando sirve para setear la cuadrícula del eje x. Cuando breaks=None se elimina la cuadrícula.
                                  # This command is used to set the x-axis grid. When breaks=None the grid is removed.
 theme_minimal()+
 ylab("Wins")
+ggtitle("Distribucion de wins")+
 facet_wrap('country')
)
# Out:
# <ggplot: (8773113232433)>

# %%
mma3['wins'].max()
mma3[mma3['wins']==mma3['wins'].max()]
# Out:
#        fighter_name location        country height  weight  \
# 2908  Travis Fulton     Iowa  United States   6'0"   205.0
#
#                 association       weight_class  wins     Estado  perdidas
# 2908  Team Peak Performance  Light Heavyweight   255  Fallecido      54.0

# %% [markdown]
# Eliminaremos este outlier
#
# We will remove this outlier

# %%
# mma3.drop([2908], axis=0)
mma3.drop([2908], axis=0, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
mma3[mma3['fighter_name']=='Travis Fulton']
# Out:
# Empty DataFrame
# Columns: [fighter_name, location, country, height, weight, association, weight_class, wins, Estado, perdidas]
# Index: []

# %% [markdown]
# Ahora volvemos a hacer nuestro boxplot
#
# Now we go back to doing our boxplot

# %%
from plotnine.themes.themeable import legend_box
(ggplot(mma3)+
 aes(x=0,y="wins",colour="country")+
 geom_boxplot()+
 scale_x_continuous(breaks=None)+ #Este comando sirve para setear la cuadrícula del eje x. Cuando breaks=None se elimina la cuadrícula.
                                  # This command is used to set the x-axis grid. When breaks=None the grid is removed.
 ylab("Wins")+
 ggtitle("Distribucion de wins")+
 facet_wrap('country')+
 theme_minimal()+
 theme(legend_position="bottom",legend_box_spacing=0.1,legend_box="horizontal")
)
# Out:
# <ggplot: (8773112864405)>

# %% [markdown]
# **Lossess**
