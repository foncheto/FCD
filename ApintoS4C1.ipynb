# %%
import pandas as pd
import numpy as np

# %%
google = pd.read_excel("datos/googleplaystore.xlsx")
google
# Out:
#                                                  App           Category  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook       Art & Design
# 1                                Coloring book moana       Art & Design
# 2                              Sketch - Draw & Paint       Art & Design
# 3              Pixel Draw - Number Art Coloring Book       Art & Design
# 4                         Paper flowers instructions       Art & Design
# ...                                              ...                ...
# 8808                                   FR Calculator          Education
# 8809                                Sya9a Maroc - FR          Education
# 8810                Fr. Mike Schmitz Audio Teachings          Education
# 8811                   The SCP Foundation DB fr nn5n  Books & Reference
# 8812   iHoroscope - 2018 Daily Horoscope & Astrology          Lifestyle
#
#       Rating  Reviews                Size                Installs  Type  \
# ...

# %% [markdown]
# Son 11 variables sin contar el indice y son 96943 datos.

# %% [markdown]
# ACTIVIDAD 2

# %% [markdown]
# App ==> Nombre comercial de la aplicacion. Variable Cualitativa Nominal que puede tomar cualquier nombre compuesto por varias palabras y/o numeros.
# Category ==> Categoria de la aplicacion. Variable Cualitativa Nominal que puede tomar uno de los generos determinados por la tienda de aplicaciones para categorizar la app dentro de un grupo de apps similares.
# Rating	==> Puntuacion promedio que ha recibido la aplicacion desde su lanzamiento por parte de los usuarios. Variable Cuantitativa Intervalar Continua. Se establece en el intervalo 0 a 5.
# Reviews	==> Numero de reseñas por parte de los usuarios subidas a la plataforma respecto de la app. Variable cuantitativa discreta. Que solo tiene limite inferior 0.
# Size ==>
# Installs
# Type
# Price
# Last Updated
# Current Ver
# Android Ver

# %% [markdown]
# ACTIVIDAD 3

# %%
limpieza = google.dropna()
limpieza
# Out:
#                                                  App           Category  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook       Art & Design
# 2                              Sketch - Draw & Paint       Art & Design
# 4                         Paper flowers instructions       Art & Design
# 5            Smoke Effect Photo Maker - Smoke Editor       Art & Design
# 6                                   Infinite Painter       Art & Design
# ...                                              ...                ...
# 8808                                   FR Calculator          Education
# 8809                                Sya9a Maroc - FR          Education
# 8810                Fr. Mike Schmitz Audio Teachings          Education
# 8811                   The SCP Foundation DB fr nn5n  Books & Reference
# 8812   iHoroscope - 2018 Daily Horoscope & Astrology          Lifestyle
#
#       Rating  Reviews                Size                Installs  Type  \
# ...

# %% [markdown]
# Nuestros nuevos datos son 91652. 5291 datos menos.

# %% [markdown]
# Actividad 4

# %% [markdown]
# Promedio Rating

# %%
np.mean(google['Rating'])
# Out:
# 4.181232270509474

# %% [markdown]
# Mediana Rating

# %%
np.median(google['Rating'])
# Out:
# 4.3

# %% [markdown]
# Varianza Rating

# %%
np.var(google['Rating'])
# Out:
# 0.27489343215048984

# %%
google[(google['Type']=='Free')]
# Out:
#                                                  App           Category  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook       Art & Design
# 1                                Coloring book moana       Art & Design
# 2                              Sketch - Draw & Paint       Art & Design
# 3              Pixel Draw - Number Art Coloring Book       Art & Design
# 4                         Paper flowers instructions       Art & Design
# ...                                              ...                ...
# 8808                                   FR Calculator          Education
# 8809                                Sya9a Maroc - FR          Education
# 8810                Fr. Mike Schmitz Audio Teachings          Education
# 8811                   The SCP Foundation DB fr nn5n  Books & Reference
# 8812   iHoroscope - 2018 Daily Horoscope & Astrology          Lifestyle
#
#       Rating  Reviews                Size                Installs  Type  \
# ...

# %%
google[(google['Installs'] == '10.001-50.000') & (google['Type']=='Free')]
# Out:
#                                                  App           Category  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook       Art & Design
# 8                      Kids Paint Free - Drawing Fun       Art & Design
# 16                          350 Diy Room Decor Ideas       Art & Design
# 23                        Harley Quinn wallpapers HD       Art & Design
# 26                             Pencil Sketch Drawing       Art & Design
# ...                                              ...                ...
# 8769                                    Union League       Role Playing
# 8770                           Fortune Quest: Savior       Role Playing
# 8789                             FR: My Famous Lover      Entertainment
# 8803                         Manga-FR - Anime Vostfr             Comics
# 8804                  Bulgarian French Dictionary Fr  Books & Reference
#
#       Rating  Reviews   Size       Installs  Type  Price      Last Updated  \
# ...

# %% [markdown]
# 866/8188 = 0.105
# 10,5% de las apps gratis

# %%
google[(google['Type']=='Paid')]
# Out:
#                                                 App          Category  Rating  \
# 208   TurboScan: scan documents and receipts in PDF          Business     4.7
# 209                  Tiny Scanner Pro: PDF Doc Scan          Business     4.8
# 262   TurboScan: scan documents and receipts in PDF          Business     4.7
# 263                  Tiny Scanner Pro: PDF Doc Scan          Business     4.8
# 389                              Puffin Browser Pro     Communication     4.0
# ...                                             ...               ...     ...
# 8704                            Fruit Ninja Classic            Arcade     4.3
# 8712                                       FO Bixby   Personalization     5.0
# 8714                                        Mu.F.O.            Arcade     5.0
# 8759                                Fast Tract Diet  Health & Fitness     4.4
# 8773                        Trine 2: Complete Story            Action     3.8
#
# ...

# %%
google[(google['Installs'] == '10.001-50.000') & (google['Type']=='Paid')]
# Out:
#                                  App          Category  Rating  Reviews  \
# 1049       My CookBook Pro (Ad Free)      Food & Drink     4.6     2129
# 1149               Meditation Studio  Health & Fitness     4.6     1026
# 1919                  LEGOÂ® Friends            Casual     4.4      854
# 1920       My Little Work â€“ Garage            Casual     4.3      560
# 1943    Tsuro - The Game of the Path             Board     4.7     2195
# ...                              ...               ...     ...      ...
# 8544                        FiSwitch             Tools     4.8      615
# 8548         Smart Wi-Fi Hotspot PRO     Communication     3.7      197
# 8549  Portable Wi-Fi hotspot Premium     Communication     3.7      481
# 8614    Ray Financial Calculator Pro           Finance     4.0       67
# 8773         Trine 2: Complete Story            Action     3.8      252
#
#                     Size       Installs  Type  Price       Last Updated  \
# ...

# %% [markdown]
# 123/625 = 0.1968
# 19.68% de las apps pagadas

# %%
google[(google['Type']=='Free')]
# Out:
#                                                  App           Category  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook       Art & Design
# 1                                Coloring book moana       Art & Design
# 2                              Sketch - Draw & Paint       Art & Design
# 3              Pixel Draw - Number Art Coloring Book       Art & Design
# 4                         Paper flowers instructions       Art & Design
# ...                                              ...                ...
# 8808                                   FR Calculator          Education
# 8809                                Sya9a Maroc - FR          Education
# 8810                Fr. Mike Schmitz Audio Teachings          Education
# 8811                   The SCP Foundation DB fr nn5n  Books & Reference
# 8812   iHoroscope - 2018 Daily Horoscope & Astrology          Lifestyle
#
#       Rating  Reviews                Size                Installs  Type  \
# ...

# %% [markdown]
# Porcentaje de apps gratis respecto al total: 8188/8813 = 0.929
# 92.9% de las apps son gratis

# %% [markdown]
# Promedio del Precio de las apps pagadas

# %%
new = google[(google['Type']=='Paid')]
np.mean(new['Price'])
# Out:
# 14.190496000000001

# %% [markdown]
# Precio promedio apps pagadas: 14.19 USD
